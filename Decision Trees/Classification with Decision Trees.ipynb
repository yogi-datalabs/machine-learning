# %% [markdown]
#  # Decision Trees

# %% [markdown]
# <font color = "brown"><font size = 5> Context </font>
#
# <font size = 3> This dataset represents customer credit information used to predict whether a borrower will default on a loan. It contains demographic information, financial history, employment details, credit account behavior, and the final repayment outcome. The goal is to build a classification model that can differentiate between customers who are likely to repay their loan on time and those who are at risk of defaulting.
#
# The dataset includes both numerical and categorical attributes (encoded as symbolic codes like A11, A12, etc.). The target variable is Default_On_Payment, where 1 indicates a loan default and 0 means successful repayment.
#
# This dataset is commonly used for credit risk modeling, enabling financial institutions to understand borrower behavior and make informed lending decisions. In this project, it will be used to demonstrate model training, evaluation, and the effect of overfitting, especially in Decision Tree–based models. </font>

# %% [markdown]
# <font size =5 color = "brown"> Data Dictionary </font>
#
# | Column Name                           | Meaning / Description                            | Data Type   | Example Values                    |
# | ------------------------------------- | ------------------------------------------------ | ----------- | --------------------------------- |
# | **Customer_ID**                       | Unique customer identifier                       | Integer     | `100001`, `100245`                |
# | **Status_Checking_Acc**               | Status of checking (current) account             | Categorical | `A11`, `A12`, `A13`, `A14`        |
# | **Duration_in_Months**                | Loan duration in months                          | Numeric     | `6`, `24`, `48`                   |
# | **Credit_History**                    | Customer credit repayment history                | Categorical | `A30`, `A31`, `A32`, `A33`, `A34` |
# | **Purposre_Credit_Taken** *(Purpose)* | Purpose of loan                                  | Categorical | `A40`, `A41`, `A42`, `A43`, `A46` |
# | **Credit_Amount**                     | Loan amount requested/approved                   | Numeric     | `1169`, `5000`, `7882`            |
# | **Savings_Acc**                       | Savings account/bond holdings                    | Categorical | `A61`, `A62`, `A63`, `A64`, `A65` |
# | **Years_At_Present_Employment**       | Employment tenure at current job                 | Categorical | `A71`, `A72`, `A73`, `A74`, `A75` |
# | **Inst_Rt_Income**                    | Installment rate as % of disposable income       | Numeric     | `1`, `2`, `3`, `4`                |
# | **Marital_Status_Gender**             | Marital status & gender combined                 | Categorical | `A91`, `A92`, `A93`, `A94`        |
# | **Guarantors**                        | Guarantor / co-applicant                         | Categorical | `A101`, `A102`, `A103`            |
# | **Residence_Duration**                | Years living at current residence                | Numeric     | `1`, `2`, `3`, `4`                |
# | **Most_Valuable_Available_Asset**     | Major assets held                                | Categorical | `A121`, `A122`, `A123`, `A124`    |
# | **Age**                               | Customer age in years                            | Numeric     | `22`, `35`, `49`, `67`            |
# | **Other_Inst_Plans**                  | Other installment plans                          | Categorical | `A141`, `A142`, `A143`            |
# | **Housing**                           | Housing status                                   | Categorical | `A151`, `A152`, `A153`            |
# | **Num_CC**                            | # of existing credit accounts                    | Numeric     | `1`, `2`, `3`                     |
# | **Job**                               | Customer job skill level                         | Categorical | `A171`, `A172`, `A173`, `A174`    |
# | **Dependents**                        | Number of financial dependents                   | Numeric     | `1`, `2`                          |
# | **Telephone**                         | Telephone availability                           | Categorical | `A191`, `A192`                    |
# | **Foreign_Worker**                    | Whether a foreign worker                         | Categorical | `A201`, `A202`                    |
# | **Default_On_Payment**                | **Target variable**: 1 = default, 0 = no default | Binary      | `0`, `1`                          |
#
# ----------------------------------

# %% [markdown]
# ## Importing the libraries

# %%
# Import necessary libraries.
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import (classification_report,confusion_matrix,
                            accuracy_score, roc_auc_score, roc_curve,
                            recall_score, precision_score, f1_score)


# To enable plotting graphs in Jupyter notebook
# %matplotlib inline
pd.set_option('display.float_format', lambda x: '%.3f' % x)# to display numbers in digits

# %% [markdown]
# ## Reading the dataset

# %%
data = pd.read_csv("default_on_payment.csv")
df = data.copy()

# %% [markdown]
# ## Checking the shape of the dataset

# %%
df.shape
# Out:
# (5000, 22)

# %% [markdown]
# We have 5000 observations with 22 features.

# %% [markdown]
# ## Checking the column names

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Status_Checking_Acc', 'Duration_in_Months',
#        'Credit_History', 'Purposre_Credit_Taken', 'Credit_Amount',
#        'Savings_Acc', 'Years_At_Present_Employment', 'Inst_Rt_Income',
#        'Marital_Status_Gender', 'Other_Debtors_Guarantors',
#        'Current_Address_Yrs', 'Property', 'Age', 'Other_Inst_Plans ',
#        'Housing', 'Num_CC', 'Job', 'Dependents', 'Telephone', 'Foreign_Worker',
#        'Default_On_Payment'],
#       dtype='object')

# %% [markdown]
# ## Dropping the customer ID

# %%
df.drop("Customer_ID", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Status_Checking_Acc          5000 non-null   object
#  1   Duration_in_Months           5000 non-null   int64
#  2   Credit_History               5000 non-null   object
#  3   Purposre_Credit_Taken        5000 non-null   object
#  4   Credit_Amount                5000 non-null   int64
#  5   Savings_Acc                  5000 non-null   object
#  6   Years_At_Present_Employment  5000 non-null   object
#  7   Inst_Rt_Income               5000 non-null   int64
#  8   Marital_Status_Gender        5000 non-null   object
#  9   Other_Debtors_Guarantors     5000 non-null   object
#  10  Current_Address_Yrs          5000 non-null   int64
#  11  Property                     5000 non-null   object
#  12  Age                          5000 non-null   int64
# ...

# %% [markdown]
# We do not have any missing values. Also, we have 8 numeric and 13 object columns.

# %% [markdown]
# <font size = 5 color = "brown"> Model Building </font>

# %% [markdown]
# Separating the X and Y variables and Using Dummies to convert the categorical columns to Numerical type

# %%
X = df.drop('Default_On_Payment', axis=1)
y = df['Default_On_Payment']

object_cols = df.select_dtypes(include=['object']).columns

X = pd.get_dummies(data = X, columns = object_cols, drop_first = True, dtype = int)


X.head()
# Out:
#    Duration_in_Months  Credit_Amount  Inst_Rt_Income  Current_Address_Yrs  \
# 0                   6           1169               4                    4
# 1                  48           5951               2                    2
# 2                  12           2096               2                    3
# 3                  42           7882               2                    4
# 4                  24           4870               3                    4
#
#    Age  Num_CC  Dependents  Status_Checking_Acc_A12  Status_Checking_Acc_A13  \
# 0   67       2           1                        0                        0
# 1   22       1           1                        1                        0
# 2   49       1           2                        0                        0
# 3   45       1           2                        0                        0
# 4   53       2           2                        0                        0
#
# ...

# %% [markdown]
# Splitting the data in train and test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # Base Decision Tree Model

# %% [markdown]
# Building a base decision tree model.

# %%
base_dtree = DecisionTreeClassifier(random_state=0)
base_dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# Predicting on the training dataset and checking the confusion matrix.

# %%
pred_train = base_dtree.predict(X_train)

confusion_matrix(y_train, pred_train)
# Out:
# array([[2056,    0],
#        [   0, 1444]], dtype=int64)

# %% [markdown]
# Predicting on the test dataset and checking the confusion matrix.

# %%
pred_test = base_dtree.predict(X_test)
confusion_matrix(y_test, pred_test)
# Out:
# array([[780, 123],
#        [ 99, 498]], dtype=int64)

# %% [markdown]
# Recall score of the train set.

# %%
recall_score(y_train, pred_train)
# Out:
# 1.0

# %% [markdown]
# Recall score of the test set.

# %%
recall_score(y_test, pred_test)
# Out:
# 0.8341708542713567

# %% [markdown]
# So, we can see here that a base decision tree is working as a fully grown tree. This is why it is also called as a greedy algorithm: it keeps splitting until every training example is classified correctly, reaching 100% recall on the training set. But that recall drops to around 83% on the test set, a clear sign of overfitting. The tree has memorised quirks of the training data that don't hold up on unseen customers. We will see next how pruning helps handle this overfitting.

# %% [markdown]
# ### Visualizing the Base Tree
#
# Let's look at what a fully grown, unrestricted tree looks like.

# %%
feature_names = list(X_train.columns)

plt.figure(figsize=(30, 15))
tree.plot_tree(
    base_dtree,
    feature_names=feature_names,
    class_names=['No Default', 'Default'],
    filled=True,
    fontsize=4,
)
plt.show()

# %% [markdown]
# This is what an unrestricted tree looks like: hundreds of splits going many levels deep. It is impossible to read or explain to a business user, and this complexity is exactly what causes the overfitting we saw above.

# %% [markdown]
# ### Feature Importance (Base Tree)
#
# Which features does the tree rely on most to make its decisions?

# %%
importances = base_dtree.feature_importances_
importance_df = pd.DataFrame(
    {'Feature': feature_names, 'Importance': importances}
).sort_values(by='Importance', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(data=importance_df, x='Importance', y='Feature')
plt.title('Top 10 Important Features - Base Tree')
plt.show()

# %% [markdown]
# ## Pre-Pruning (Hyperparameter Tuning)
#
# The base tree above grew without any limits, so it memorised the training data but generalised poorly to the test data. This is overfitting.
#
# **Pre-pruning** fixes this by stopping the tree from growing too deep in the first place. We set limits like `max_depth` (how many questions deep the tree can go) and `min_samples_leaf` (minimum data points required in a final leaf) *before* training, and let `GridSearchCV` search for the best combination.

# %%
# Defining the parameter grid to search over
params_grid = {
    'max_depth': [3, 4, 5, 6, 7],
    'min_samples_leaf': [5, 10, 20, 30],
    'criterion': ['gini', 'entropy'],
}

estimator = DecisionTreeClassifier(random_state=0)

grid_search = GridSearchCV(estimator, params_grid, scoring='recall', cv=5, n_jobs=-1)
grid_search.fit(X_train, y_train)

print("Best parameters found:", grid_search.best_params_)
# Out:
# Best parameters found: {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 5}

# %% [markdown]
# Using the best parameters found by `GridSearchCV` to build the pre-pruned tree.

# %%
pre_pruned_dtree = grid_search.best_estimator_
pre_pruned_dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, min_samples_leaf=5, random_state=0)

# %% [markdown]
# Predicting on the training dataset and checking the confusion matrix.

# %%
pred_train_pre = pre_pruned_dtree.predict(X_train)
confusion_matrix(y_train, pred_train_pre)
# Out:
# array([[1933,  123],
#        [ 352, 1092]], dtype=int64)

# %% [markdown]
# Predicting on the test dataset and checking the confusion matrix.

# %%
pred_test_pre = pre_pruned_dtree.predict(X_test)
confusion_matrix(y_test, pred_test_pre)
# Out:
# array([[855,  48],
#        [130, 467]], dtype=int64)

# %% [markdown]
# Recall score of the train set.

# %%
recall_score(y_train, pred_train_pre)
# Out:
# 0.7562326869806094

# %% [markdown]
# Recall score of the test set.

# %%
recall_score(y_test, pred_test_pre)
# Out:
# 0.7822445561139029

# %% [markdown]
# Capping the tree's depth brings training recall down closer to test recall, i.e. a much smaller train-test gap than the base model. However, the pre-pruned tree here is a little too conservative: by restricting how deep it can grow, it also gives up some real signal, so its test recall (~78%) actually ends up a bit lower than what the base tree gets, even though it generalises more consistently. This shows pre-pruning's limitation: fixing `max_depth` upfront is a blunt tool, it can under-fit if set too aggressively.

# %% [markdown]
# ### Visualizing the Pre-Pruned Tree
#
# Let's look at the actual splits the tree learned. This makes the model's decisions easy to explain to a non-technical audience.

# %%
plt.figure(figsize=(20, 10))
tree.plot_tree(
    pre_pruned_dtree,
    feature_names=feature_names,
    class_names=['No Default', 'Default'],
    filled=True,
    fontsize=9,
)
plt.show()

# %% [markdown]
# ### Feature Importance (Pre-Pruned Tree)
#
# Which features does the tree rely on most to make its decisions?

# %%
importances = pre_pruned_dtree.feature_importances_
importance_df = pd.DataFrame(
    {'Feature': feature_names, 'Importance': importances}
).sort_values(by='Importance', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(data=importance_df, x='Importance', y='Feature')
plt.title('Top 10 Important Features - Pre-Pruned Tree')
plt.show()

# %% [markdown]
# `Status_Checking_Acc`, `Credit_Amount`, and `Age` tend to be among the strongest signals the tree uses to decide whether a customer will default. (Exact ranking may vary slightly depending on the tuned parameters.)

# %% [markdown]
# ## Post-Pruning (Cost Complexity Pruning)
#
# Instead of limiting the tree's growth beforehand, **post-pruning** lets the tree grow fully first and then trims back branches that add little value. This is controlled by a single parameter, `ccp_alpha`: the larger the value, the more the tree gets pruned.
#
# We will try a range of `ccp_alpha` values and, for each one, look at both the test recall and the gap between train and test recall. We want a tree that scores well on the test set **and** doesn't have a big train-test gap, since a big gap means the tree is still overfitting even if its test score looks decent.

# %%
# Growing a full tree first to get the range of ccp_alpha values to try
full_dtree = DecisionTreeClassifier(random_state=0)
path = full_dtree.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas = path.ccp_alphas[:-1]  # dropping the last value, which prunes the tree down to a single node
ccp_alphas = ccp_alphas[ccp_alphas >= 0]  # tiny negative values can appear due to floating-point rounding

# %%
# Training a tree for each ccp_alpha and recording train/test recall scores
train_scores, test_scores = [], []

for alpha in ccp_alphas:
    clf = DecisionTreeClassifier(random_state=0, ccp_alpha=alpha)
    clf.fit(X_train, y_train)
    train_scores.append(recall_score(y_train, clf.predict(X_train)))
    test_scores.append(recall_score(y_test, clf.predict(X_test)))

# %%
plt.figure(figsize=(10, 6))
plt.plot(ccp_alphas, train_scores, marker='o', label='Train Recall', drawstyle='steps-post')
plt.plot(ccp_alphas, test_scores, marker='o', label='Test Recall', drawstyle='steps-post')
plt.xlabel('ccp_alpha')
plt.ylabel('Recall Score')
plt.title('Recall Score vs ccp_alpha')
plt.legend()
plt.show()

# %% [markdown]
# Picking the `ccp_alpha` that gives the best combination of high test recall and a small train-test gap: for every alpha we compute `test recall - |train recall - test recall|`, and pick the alpha that maximises this. This rewards trees that generalise well (high test recall) *and* generalise consistently (train and test recall close to each other), rather than just chasing the single highest test score.

# %%
# For each ccp_alpha, balance two things: how high is test recall, and how small is the train-test gap.
# score = test_recall - |train_recall - test_recall|  -> rewards high test recall AND a small gap
gaps = [abs(tr - te) for tr, te in zip(train_scores, test_scores)]
combined_score = [te - gap for te, gap in zip(test_scores, gaps)]

best_index = combined_score.index(max(combined_score))
best_alpha = ccp_alphas[best_index]

print("Best ccp_alpha:", best_alpha)
print("Train recall at best alpha:", train_scores[best_index])
print("Test recall at best alpha:", test_scores[best_index])
print("Train-test gap at best alpha:", gaps[best_index])

post_pruned_dtree = DecisionTreeClassifier(random_state=0, ccp_alpha=best_alpha)
post_pruned_dtree.fit(X_train, y_train)
# Out:
# Best ccp_alpha: 0.0017957351290684618
# Train recall at best alpha: 0.8981994459833795
# Test recall at best alpha: 0.897822445561139
# Train-test gap at best alpha: 0.00037700042224053654
# DecisionTreeClassifier(ccp_alpha=0.0017957351290684618, random_state=0)

# %% [markdown]
# Predicting on the training dataset and checking the confusion matrix.

# %%
pred_train_post = post_pruned_dtree.predict(X_train)
confusion_matrix(y_train, pred_train_post)
# Out:
# array([[1903,  153],
#        [ 147, 1297]], dtype=int64)

# %% [markdown]
# Predicting on the test dataset and checking the confusion matrix.

# %%
pred_test_post = post_pruned_dtree.predict(X_test)
confusion_matrix(y_test, pred_test_post)
# Out:
# array([[809,  94],
#        [ 61, 536]], dtype=int64)

# %% [markdown]
# Recall score of the train set.

# %%
recall_score(y_train, pred_train_post)
# Out:
# 0.8981994459833795

# %% [markdown]
# Recall score of the test set.

# %%
recall_score(y_test, pred_test_post)
# Out:
# 0.897822445561139

# %% [markdown]
# Unlike pre-pruning, post-pruning doesn't fix a single depth upfront, it grows the full tree first and then trims back only the branches that hurt generalisation, using the balanced score defined above. Here that gives a `ccp_alpha` of about 0.0018, and the resulting tree gets ~90% recall on both train and test (a gap of well under 1%). It doesn't chase the single highest test score the way a pure test-recall search would, it instead lands on a tree that performs consistently on data it hasn't seen, which is a stronger, more trustworthy result than either the overfit base tree (100% / 83%) or the overly conservative pre-pruned tree (76% / 78%).

# %% [markdown]
# ### Visualizing the Post-Pruned Tree
#
# Let's look at the actual splits the tree learned after cost-complexity pruning.

# %%
plt.figure(figsize=(20, 10))
tree.plot_tree(
    post_pruned_dtree,
    feature_names=feature_names,
    class_names=['No Default', 'Default'],
    filled=True,
    fontsize=9,
)
plt.show()

# %% [markdown]
# ### Feature Importance (Post-Pruned Tree)
#
# Which features does the tree rely on most to make its decisions?

# %%
importances = post_pruned_dtree.feature_importances_
importance_df = pd.DataFrame(
    {'Feature': feature_names, 'Importance': importances}
).sort_values(by='Importance', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(data=importance_df, x='Importance', y='Feature')
plt.title('Top 10 Important Features - Post-Pruned Tree')
plt.show()

# %% [markdown]
# ## Comparing All Three Models
#
# Let's put the train and test recall scores of all three trees side by side to pick the best model.

# %%
comparison_df = pd.DataFrame({
    'Model': ['Base Decision Tree', 'Pre-Pruned Decision Tree', 'Post-Pruned Decision Tree'],
    'Train Recall': [
        recall_score(y_train, pred_train),
        recall_score(y_train, pred_train_pre),
        recall_score(y_train, pred_train_post),
    ],
    'Test Recall': [
        recall_score(y_test, pred_test),
        recall_score(y_test, pred_test_pre),
        recall_score(y_test, pred_test_post),
    ],
})
comparison_df
# Out:
#                        Model  Train Recall  Test Recall
# 0         Base Decision Tree         1.000        0.834
# 1   Pre-Pruned Decision Tree         0.756        0.782
# 2  Post-Pruned Decision Tree         0.898        0.898

# %% [markdown]
# ## Conclusion
#
# - The **base decision tree** grows without any limits, so it reaches 100% recall on the training data but drops to around 83% on the test data. This gap is a classic sign of overfitting, the tree has learned some patterns that are specific to the training sample and don't generalise.
# - **Pre-pruning** (limiting `max_depth` and `min_samples_leaf` upfront using `GridSearchCV`) closes the train-test gap, but the fixed depth cap turns out to be a bit too restrictive here, so its test recall (~78%) ends up slightly below the base tree's.
# - **Post-pruning** (growing a full tree and trimming it back using `ccp_alpha`) does best overall: rather than just picking the alpha with the single highest test recall, we picked the alpha that balances high test recall *with* a small train-test gap. That lands on `ccp_alpha` ≈ 0.0018, giving ~90% recall on both train and test, a consistent, trustworthy result rather than a lucky peak.
# - Features such as `Status_Checking_Acc`, `Credit_Amount`, and `Age` are the strongest drivers of loan default in this dataset.
# - For deployment, the **post-pruned tree** is the best choice here: it gives strong, consistent recall on both training and unseen data, while still being far simpler and more explainable than the fully grown base tree.
